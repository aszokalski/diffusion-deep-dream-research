# %% [markdown]
# # 01 Stable Diffusion v1.5 model exploration

# %%
from diffusers import StableDiffusionPipeline
import torch
from matplotlib import pyplot as plt
import cv2
import numpy as np
import torchinfo
import torchview

# %%
model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("mps")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
prompt = "a photo of an astronaut riding a horse on mars"
image_pil = pipe(prompt).images[0]

# %%
plt.imshow(image_pil)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Exploring the infrastructure

# %%
torchinfo.summary(pipe.unet, depth=5)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                                            Param #
# ==========================================================================================
# UNet2DConditionModel                                              --
# ├─Conv2d: 1-1                                                     11,840
# ├─Timesteps: 1-2                                                  --
# ├─TimestepEmbedding: 1-3                                          --
# │    └─Linear: 2-1                                                410,880
# │    └─SiLU: 2-2                                                  --
# │    └─Linear: 2-3                                                1,639,680
# ├─ModuleList: 1-4                                                 --
# │    └─CrossAttnDownBlock2D: 2-4                                  --
# │    │    └─ModuleList: 3-1                                       --
# │    │    │    └─Transformer2DModel: 4-1                          --
# │    │    │    │    └─GroupNorm: 5-1                              640
# │    │    │    │    └─Conv2d: 5-2                                 102,720
# │    │    │    │    └─ModuleList: 5-3                             2,340,160
# │    │    │    │    └─Conv2d: 5-4                                 102,720
# │    │    │    └─Transformer2DModel: 4-2                          --
# │    │    │    │    └─GroupNorm: 5-5                              640
# │    │    │    │    └─Conv2d: 5-6                                 102,720
# │    │    │    │    └─ModuleList: 5-7                             2,340,160
# │    │    │    │    └─Conv2d: 5-8                                 102,720
# │    │    └─ModuleList: 3-2                                       --
# │    │    │    └─ResnetBlock2D: 4-3                               --
# │    │    │    │    └─GroupNorm: 5-9                              640
# │    │    │    │    └─Conv2d: 5-10                                921,920
# │    │    │    │    └─Linear: 5-11                                409,920
# │    │    │    │    └─GroupNorm: 5-12                             640
# │    │    │    │    └─Dropout: 5-13                               --
# │    │    │    │    └─Conv2d: 5-14                                921,920
# │    │    │    │    └─SiLU: 5-15                                  --
# │    │    │    └─ResnetBlock2D: 4-4                               --
# │    │    │    │    └─GroupNorm: 5-16                             640
# │    │    │    │    └─Conv2d: 5-17                                921,920
# │    │    │    │    └─Linear: 5-18                                409,920
# │    │    │    │    └─GroupNorm: 5-19                             640
# │    │    │    │    └─Dropout: 5-20                               --
# │    │    │    │    └─Conv2d: 5-21                                921,920
# │    │    │    │    └─SiLU: 5-22                                  --
# │    │    └─ModuleList: 3-3                                       --
# │    │    │    └─Downsample2D: 4-5                                --
# │    │    │    │    └─Conv2d: 5-23                                921,920
# │    └─CrossAttnDownBlock2D: 2-5                                  --
# │    │    └─ModuleList: 3-4                                       --
# │    │    │    └─Transformer2DModel: 4-6                          --
# │    │    │    │    └─GroupNorm: 5-24                             1,280
# │    │    │    │    └─Conv2d: 5-25                                410,240
# │    │    │    │    └─ModuleList: 5-26                            8,366,720
# │    │    │    │    └─Conv2d: 5-27                                410,240
# │    │    │    └─Transformer2DModel: 4-7                          --
# │    │    │    │    └─GroupNorm: 5-28                             1,280
# │    │    │    │    └─Conv2d: 5-29                                410,240
# │    │    │    │    └─ModuleList: 5-30                            8,366,720
# │    │    │    │    └─Conv2d: 5-31                                410,240
# │    │    └─ModuleList: 3-5                                       --
# │    │    │    └─ResnetBlock2D: 4-8                               --
# │    │    │    │    └─GroupNorm: 5-32                             640
# │    │    │    │    └─Conv2d: 5-33                                1,843,840
# │    │    │    │    └─Linear: 5-34                                819,840
# │    │    │    │    └─GroupNorm: 5-35                             1,280
# │    │    │    │    └─Dropout: 5-36                               --
# │    │    │    │    └─Conv2d: 5-37                                3,687,040
# │    │    │    │    └─SiLU: 5-38                                  --
# │    │    │    │    └─Conv2d: 5-39                                205,440
# │    │    │    └─ResnetBlock2D: 4-9                               --
# │    │    │    │    └─GroupNorm: 5-40                             1,280
# │    │    │    │    └─Conv2d: 5-41                                3,687,040
# │    │    │    │    └─Linear: 5-42                                819,840
# │    │    │    │    └─GroupNorm: 5-43                             1,280
# │    │    │    │    └─Dropout: 5-44                               --
# │    │    │    │    └─Conv2d: 5-45                                3,687,040
# │    │    │    │    └─SiLU: 5-46                                  --
# │    │    └─ModuleList: 3-6                                       --
# │    │    │    └─Downsample2D: 4-10                               --
# │    │    │    │    └─Conv2d: 5-47                                3,687,040
# │    └─CrossAttnDownBlock2D: 2-6                                  --
# │    │    └─ModuleList: 3-7                                       --
# │    │    │    └─Transformer2DModel: 4-11                         --
# │    │    │    │    └─GroupNorm: 5-48                             2,560
# │    │    │    │    └─Conv2d: 5-49                                1,639,680
# │    │    │    │    └─ModuleList: 5-50                            31,479,040
# │    │    │    │    └─Conv2d: 5-51                                1,639,680
# │    │    │    └─Transformer2DModel: 4-12                         --
# │    │    │    │    └─GroupNorm: 5-52                             2,560
# │    │    │    │    └─Conv2d: 5-53                                1,639,680
# │    │    │    │    └─ModuleList: 5-54                            31,479,040
# │    │    │    │    └─Conv2d: 5-55                                1,639,680
# │    │    └─ModuleList: 3-8                                       --
# │    │    │    └─ResnetBlock2D: 4-13                              --
# │    │    │    │    └─GroupNorm: 5-56                             1,280
# │    │    │    │    └─Conv2d: 5-57                                7,374,080
# │    │    │    │    └─Linear: 5-58                                1,639,680
# │    │    │    │    └─GroupNorm: 5-59                             2,560
# │    │    │    │    └─Dropout: 5-60                               --
# │    │    │    │    └─Conv2d: 5-61                                14,746,880
# │    │    │    │    └─SiLU: 5-62                                  --
# │    │    │    │    └─Conv2d: 5-63                                820,480
# │    │    │    └─ResnetBlock2D: 4-14                              --
# │    │    │    │    └─GroupNorm: 5-64                             2,560
# │    │    │    │    └─Conv2d: 5-65                                14,746,880
# │    │    │    │    └─Linear: 5-66                                1,639,680
# │    │    │    │    └─GroupNorm: 5-67                             2,560
# │    │    │    │    └─Dropout: 5-68                               --
# │    │    │    │    └─Conv2d: 5-69                                14,746,880
# │    │    │    │    └─SiLU: 5-70                                  --
# │    │    └─ModuleList: 3-9                                       --
# │    │    │    └─Downsample2D: 4-15                               --
# │    │    │    │    └─Conv2d: 5-71                                14,746,880
# │    └─DownBlock2D: 2-7                                           --
# │    │    └─ModuleList: 3-10                                      --
# │    │    │    └─ResnetBlock2D: 4-16                              --
# │    │    │    │    └─GroupNorm: 5-72                             2,560
# │    │    │    │    └─Conv2d: 5-73                                14,746,880
# │    │    │    │    └─Linear: 5-74                                1,639,680
# │    │    │    │    └─GroupNorm: 5-75                             2,560
# │    │    │    │    └─Dropout: 5-76                               --
# │    │    │    │    └─Conv2d: 5-77                                14,746,880
# │    │    │    │    └─SiLU: 5-78                                  --
# │    │    │    └─ResnetBlock2D: 4-17                              --
# │    │    │    │    └─GroupNorm: 5-79                             2,560
# │    │    │    │    └─Conv2d: 5-80                                14,746,880
# │    │    │    │    └─Linear: 5-81                                1,639,680
# │    │    │    │    └─GroupNorm: 5-82                             2,560
# │    │    │    │    └─Dropout: 5-83                               --
# │    │    │    │    └─Conv2d: 5-84                                14,746,880
# │    │    │    │    └─SiLU: 5-85                                  --
# ├─ModuleList: 1-5                                                 --
# │    └─UpBlock2D: 2-8                                             --
# │    │    └─ModuleList: 3-11                                      --
# │    │    │    └─ResnetBlock2D: 4-18                              --
# │    │    │    │    └─GroupNorm: 5-86                             5,120
# │    │    │    │    └─Conv2d: 5-87                                29,492,480
# │    │    │    │    └─Linear: 5-88                                1,639,680
# │    │    │    │    └─GroupNorm: 5-89                             2,560
# │    │    │    │    └─Dropout: 5-90                               --
# │    │    │    │    └─Conv2d: 5-91                                14,746,880
# │    │    │    │    └─SiLU: 5-92                                  --
# │    │    │    │    └─Conv2d: 5-93                                3,278,080
# │    │    │    └─ResnetBlock2D: 4-19                              --
# │    │    │    │    └─GroupNorm: 5-94                             5,120
# │    │    │    │    └─Conv2d: 5-95                                29,492,480
# │    │    │    │    └─Linear: 5-96                                1,639,680
# │    │    │    │    └─GroupNorm: 5-97                             2,560
# │    │    │    │    └─Dropout: 5-98                               --
# │    │    │    │    └─Conv2d: 5-99                                14,746,880
# │    │    │    │    └─SiLU: 5-100                                 --
# │    │    │    │    └─Conv2d: 5-101                               3,278,080
# │    │    │    └─ResnetBlock2D: 4-20                              --
# │    │    │    │    └─GroupNorm: 5-102                            5,120
# │    │    │    │    └─Conv2d: 5-103                               29,492,480
# │    │    │    │    └─Linear: 5-104                               1,639,680
# │    │    │    │    └─GroupNorm: 5-105                            2,560
# │    │    │    │    └─Dropout: 5-106                              --
# │    │    │    │    └─Conv2d: 5-107                               14,746,880
# │    │    │    │    └─SiLU: 5-108                                 --
# │    │    │    │    └─Conv2d: 5-109                               3,278,080
# │    │    └─ModuleList: 3-12                                      --
# │    │    │    └─Upsample2D: 4-21                                 --
# │    │    │    │    └─Conv2d: 5-110                               14,746,880
# │    └─CrossAttnUpBlock2D: 2-9                                    --
# │    │    └─ModuleList: 3-13                                      --
# │    │    │    └─Transformer2DModel: 4-22                         --
# │    │    │    │    └─GroupNorm: 5-111                            2,560
# │    │    │    │    └─Conv2d: 5-112                               1,639,680
# │    │    │    │    └─ModuleList: 5-113                           31,479,040
# │    │    │    │    └─Conv2d: 5-114                               1,639,680
# │    │    │    └─Transformer2DModel: 4-23                         --
# │    │    │    │    └─GroupNorm: 5-115                            2,560
# │    │    │    │    └─Conv2d: 5-116                               1,639,680
# │    │    │    │    └─ModuleList: 5-117                           31,479,040
# │    │    │    │    └─Conv2d: 5-118                               1,639,680
# │    │    │    └─Transformer2DModel: 4-24                         --
# │    │    │    │    └─GroupNorm: 5-119                            2,560
# │    │    │    │    └─Conv2d: 5-120                               1,639,680
# │    │    │    │    └─ModuleList: 5-121                           31,479,040
# │    │    │    │    └─Conv2d: 5-122                               1,639,680
# │    │    └─ModuleList: 3-14                                      --
# │    │    │    └─ResnetBlock2D: 4-25                              --
# │    │    │    │    └─GroupNorm: 5-123                            5,120
# │    │    │    │    └─Conv2d: 5-124                               29,492,480
# │    │    │    │    └─Linear: 5-125                               1,639,680
# │    │    │    │    └─GroupNorm: 5-126                            2,560
# │    │    │    │    └─Dropout: 5-127                              --
# │    │    │    │    └─Conv2d: 5-128                               14,746,880
# │    │    │    │    └─SiLU: 5-129                                 --
# │    │    │    │    └─Conv2d: 5-130                               3,278,080
# │    │    │    └─ResnetBlock2D: 4-26                              --
# │    │    │    │    └─GroupNorm: 5-131                            5,120
# │    │    │    │    └─Conv2d: 5-132                               29,492,480
# │    │    │    │    └─Linear: 5-133                               1,639,680
# │    │    │    │    └─GroupNorm: 5-134                            2,560
# │    │    │    │    └─Dropout: 5-135                              --
# │    │    │    │    └─Conv2d: 5-136                               14,746,880
# │    │    │    │    └─SiLU: 5-137                                 --
# │    │    │    │    └─Conv2d: 5-138                               3,278,080
# │    │    │    └─ResnetBlock2D: 4-27                              --
# │    │    │    │    └─GroupNorm: 5-139                            3,840
# │    │    │    │    └─Conv2d: 5-140                               22,119,680
# │    │    │    │    └─Linear: 5-141                               1,639,680
# │    │    │    │    └─GroupNorm: 5-142                            2,560
# │    │    │    │    └─Dropout: 5-143                              --
# │    │    │    │    └─Conv2d: 5-144                               14,746,880
# │    │    │    │    └─SiLU: 5-145                                 --
# │    │    │    │    └─Conv2d: 5-146                               2,458,880
# │    │    └─ModuleList: 3-15                                      --
# │    │    │    └─Upsample2D: 4-28                                 --
# │    │    │    │    └─Conv2d: 5-147                               14,746,880
# │    └─CrossAttnUpBlock2D: 2-10                                   --
# │    │    └─ModuleList: 3-16                                      --
# │    │    │    └─Transformer2DModel: 4-29                         --
# │    │    │    │    └─GroupNorm: 5-148                            1,280
# │    │    │    │    └─Conv2d: 5-149                               410,240
# │    │    │    │    └─ModuleList: 5-150                           8,366,720
# │    │    │    │    └─Conv2d: 5-151                               410,240
# │    │    │    └─Transformer2DModel: 4-30                         --
# │    │    │    │    └─GroupNorm: 5-152                            1,280
# │    │    │    │    └─Conv2d: 5-153                               410,240
# │    │    │    │    └─ModuleList: 5-154                           8,366,720
# │    │    │    │    └─Conv2d: 5-155                               410,240
# │    │    │    └─Transformer2DModel: 4-31                         --
# │    │    │    │    └─GroupNorm: 5-156                            1,280
# │    │    │    │    └─Conv2d: 5-157                               410,240
# │    │    │    │    └─ModuleList: 5-158                           8,366,720
# │    │    │    │    └─Conv2d: 5-159                               410,240
# │    │    └─ModuleList: 3-17                                      --
# │    │    │    └─ResnetBlock2D: 4-32                              --
# │    │    │    │    └─GroupNorm: 5-160                            3,840
# │    │    │    │    └─Conv2d: 5-161                               11,059,840
# │    │    │    │    └─Linear: 5-162                               819,840
# │    │    │    │    └─GroupNorm: 5-163                            1,280
# │    │    │    │    └─Dropout: 5-164                              --
# │    │    │    │    └─Conv2d: 5-165                               3,687,040
# │    │    │    │    └─SiLU: 5-166                                 --
# │    │    │    │    └─Conv2d: 5-167                               1,229,440
# │    │    │    └─ResnetBlock2D: 4-33                              --
# │    │    │    │    └─GroupNorm: 5-168                            2,560
# │    │    │    │    └─Conv2d: 5-169                               7,373,440
# │    │    │    │    └─Linear: 5-170                               819,840
# │    │    │    │    └─GroupNorm: 5-171                            1,280
# │    │    │    │    └─Dropout: 5-172                              --
# │    │    │    │    └─Conv2d: 5-173                               3,687,040
# │    │    │    │    └─SiLU: 5-174                                 --
# │    │    │    │    └─Conv2d: 5-175                               819,840
# │    │    │    └─ResnetBlock2D: 4-34                              --
# │    │    │    │    └─GroupNorm: 5-176                            1,920
# │    │    │    │    └─Conv2d: 5-177                               5,530,240
# │    │    │    │    └─Linear: 5-178                               819,840
# │    │    │    │    └─GroupNorm: 5-179                            1,280
# │    │    │    │    └─Dropout: 5-180                              --
# │    │    │    │    └─Conv2d: 5-181                               3,687,040
# │    │    │    │    └─SiLU: 5-182                                 --
# │    │    │    │    └─Conv2d: 5-183                               615,040
# │    │    └─ModuleList: 3-18                                      --
# │    │    │    └─Upsample2D: 4-35                                 --
# │    │    │    │    └─Conv2d: 5-184                               3,687,040
# │    └─CrossAttnUpBlock2D: 2-11                                   --
# │    │    └─ModuleList: 3-19                                      --
# │    │    │    └─Transformer2DModel: 4-36                         --
# │    │    │    │    └─GroupNorm: 5-185                            640
# │    │    │    │    └─Conv2d: 5-186                               102,720
# │    │    │    │    └─ModuleList: 5-187                           2,340,160
# │    │    │    │    └─Conv2d: 5-188                               102,720
# │    │    │    └─Transformer2DModel: 4-37                         --
# │    │    │    │    └─GroupNorm: 5-189                            640
# │    │    │    │    └─Conv2d: 5-190                               102,720
# │    │    │    │    └─ModuleList: 5-191                           2,340,160
# │    │    │    │    └─Conv2d: 5-192                               102,720
# │    │    │    └─Transformer2DModel: 4-38                         --
# │    │    │    │    └─GroupNorm: 5-193                            640
# │    │    │    │    └─Conv2d: 5-194                               102,720
# │    │    │    │    └─ModuleList: 5-195                           2,340,160
# │    │    │    │    └─Conv2d: 5-196                               102,720
# │    │    └─ModuleList: 3-20                                      --
# │    │    │    └─ResnetBlock2D: 4-39                              --
# │    │    │    │    └─GroupNorm: 5-197                            1,920
# │    │    │    │    └─Conv2d: 5-198                               2,765,120
# │    │    │    │    └─Linear: 5-199                               409,920
# │    │    │    │    └─GroupNorm: 5-200                            640
# │    │    │    │    └─Dropout: 5-201                              --
# │    │    │    │    └─Conv2d: 5-202                               921,920
# │    │    │    │    └─SiLU: 5-203                                 --
# │    │    │    │    └─Conv2d: 5-204                               307,520
# │    │    │    └─ResnetBlock2D: 4-40                              --
# │    │    │    │    └─GroupNorm: 5-205                            1,280
# │    │    │    │    └─Conv2d: 5-206                               1,843,520
# │    │    │    │    └─Linear: 5-207                               409,920
# │    │    │    │    └─GroupNorm: 5-208                            640
# │    │    │    │    └─Dropout: 5-209                              --
# │    │    │    │    └─Conv2d: 5-210                               921,920
# │    │    │    │    └─SiLU: 5-211                                 --
# │    │    │    │    └─Conv2d: 5-212                               205,120
# │    │    │    └─ResnetBlock2D: 4-41                              --
# │    │    │    │    └─GroupNorm: 5-213                            1,280
# │    │    │    │    └─Conv2d: 5-214                               1,843,520
# │    │    │    │    └─Linear: 5-215                               409,920
# │    │    │    │    └─GroupNorm: 5-216                            640
# │    │    │    │    └─Dropout: 5-217                              --
# │    │    │    │    └─Conv2d: 5-218                               921,920
# │    │    │    │    └─SiLU: 5-219                                 --
# │    │    │    │    └─Conv2d: 5-220                               205,120
# ├─UNetMidBlock2DCrossAttn: 1-6                                    --
# │    └─ModuleList: 2-12                                           --
# │    │    └─Transformer2DModel: 3-21                              --
# │    │    │    └─GroupNorm: 4-42                                  2,560
# │    │    │    └─Conv2d: 4-43                                     1,639,680
# │    │    │    └─ModuleList: 4-44                                 --
# │    │    │    │    └─BasicTransformerBlock: 5-221                31,479,040
# │    │    │    └─Conv2d: 4-45                                     1,639,680
# │    └─ModuleList: 2-13                                           --
# │    │    └─ResnetBlock2D: 3-22                                   --
# │    │    │    └─GroupNorm: 4-46                                  2,560
# │    │    │    └─Conv2d: 4-47                                     14,746,880
# │    │    │    └─Linear: 4-48                                     1,639,680
# │    │    │    └─GroupNorm: 4-49                                  2,560
# │    │    │    └─Dropout: 4-50                                    --
# │    │    │    └─Conv2d: 4-51                                     14,746,880
# │    │    │    └─SiLU: 4-52                                       --
# │    │    └─ResnetBlock2D: 3-23                                   --
# │    │    │    └─GroupNorm: 4-53                                  2,560
# │    │    │    └─Conv2d: 4-54                                     14,746,880
# │    │    │    └─Linear: 4-55                                     1,639,680
# │    │    │    └─GroupNorm: 4-56                                  2,560
# │    │    │    └─Dropout: 4-57                                    --
# │    │    │    └─Conv2d: 4-58                                     14,746,880
# │    │    │    └─SiLU: 4-59                                       --
# ├─GroupNorm: 1-7                                                  640
# ├─SiLU: 1-8                                                       --
# ├─Conv2d: 1-9                                                     11,524
# ==========================================================================================
# Total params: 859,520,964
# Trainable params: 859,520,964
# Non-trainable params: 0
# ==========================================================================================

# %% [markdown]
# Down blocks have cross-attention layers as well

# %%
import torch
from torchview import draw_graph

# 1. Get the correct configuration
batch_size = 1
height = pipe.unet.config.sample_size
width = pipe.unet.config.sample_size
latents_shape = (batch_size, pipe.unet.config.in_channels, height, width)
prompt_shape = (batch_size, 77, pipe.unet.config.cross_attention_dim)

# 2. Create Dummy Inputs with the CORRECT DTYPE
# We add `dtype=pipe.unet.dtype` to match the model (float16 or float32)
dummy_latents = torch.randn(latents_shape, dtype=pipe.unet.dtype, device=pipe.device)
dummy_context = torch.randn(prompt_shape, dtype=pipe.unet.dtype, device=pipe.device)

# Timestep remains a standard tensor (usually int/long, converted internally)
dummy_timestep = torch.tensor([1], device=pipe.device)

# 3. Draw Graph
graph = draw_graph(
    pipe.unet,
    input_data=(dummy_latents, dummy_timestep, dummy_context),
    expand_nested=True,
    depth=2,
    save_graph=True,
    filename="unet_architecture"
)

graph.visual_graph.render(format="png")
print("Graph rendered successfully.")
# Out:
# Graph rendered successfully.

# %%
from graphviz_anywidget import graphviz_widget
graphviz_widget(graph.visual_graph.source)
# Out:
# VBox(children=(HBox(children=(Button(button_style='warning', description='Reset', icon='refresh', layout=Layou…
