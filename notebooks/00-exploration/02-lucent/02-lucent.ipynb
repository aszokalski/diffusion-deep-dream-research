# %% [markdown]
# # 02: Lucent

# %% [markdown]
# I've added MPS support to lucent https://github.com/aszokalski/lucent

# %%
# %env PYTORCH_ENABLE_MPS_FALLBACK=1
# Out:
# env: PYTORCH_ENABLE_MPS_FALLBACK=1

# %%
import torch

from lucent.optvis import render, param, transform, objectives
from lucent.modelzoo import inceptionv1
import lucent.util as ut

# %%
backend_name = "cuda:0" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
backend_name
# Out:
# 'mps'

# %%
device = ut.set_default_device(backend_name)
device
# Out:
# device(type='cpu')

# %%
model = inceptionv1(pretrained=True)
_ = model.to(device).eval()

# %%
_ = render.render_vis(model, "mixed4a:479", show_inline=True)
# Out:
# 100%|██████████| 512/512 [00:49<00:00, 10.36it/s]
# <div style="display: flex; flex-direction: row;"><div style="margin-right:10px; margin-top: 4px;">
#                             0 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div></div>
